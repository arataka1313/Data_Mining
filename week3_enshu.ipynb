# %%
import numpy as np

def true_function(x):
    return np.sin(np.pi * x * 0.8) * 10

# 例として、入力としてNumPy配列を作成して関数に渡し、出力を得る
x_values = np.array([0, 1, 2, 3, 4])
y_values = true_function(x_values)

print(y_values)
# Out:
# [ 0.          5.87785252 -9.51056516  9.51056516 -5.87785252]

# %%
import numpy as np
import matplotlib.pyplot as plt

# 真の関数を定義
def true_function(x):
    return np.sin(np.pi * x * 0.8) * 10

# 定義域を設定
x_values = np.linspace(-1, 1, 100)  # -1から1まで100点で区切る

# 関数を計算
y_values = true_function(x_values)

# グラフを描画
plt.plot(x_values, y_values, label='y = sin(pi * x * 0.8) * 10')

# グラフのタイトルと軸ラベルを設定
plt.title('True Function')
plt.xlabel('x')
plt.ylabel('y')

# 凡例を表示
plt.legend()

# グラフをファイルに保存
plt.savefig('ex1.1.png')

# グラフを表示
plt.show()
